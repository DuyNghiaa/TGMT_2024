# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path =  'C:/Users/user/Thị giác máy tính/image/1.jpg'

# %%
img = load_image(my_path)

# %%
img_rotate = img.rotate(90)
display(img_rotate)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img_rotate1 = img_rotate.rotate(90)
display(img_rotate1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img_transpose = img.transpose(Image.Transpose.ROTATE_180)
display(img_transpose)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
