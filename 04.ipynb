# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/user/Documents/Thị giác máy tính/image/1.jpg'

# %%
img = load_image(my_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
region = (80,90,200,175)
cropped_image =  img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=120x85>

# %%
paste_position = (200, 200)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
