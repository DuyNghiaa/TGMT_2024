# %%
from PIL import Image #related to image
from IPython.display import display #to display image
from imgtools import * #to use imgtools

# %%
# create directory path
mydir = 'C:/Users/user/Documents/Thị giác máy tính/image'

# %%
# create img1 path and read image
img1_path = mydir + '/1.jpg'
img1 = Image.open(img1_path)

# %%
# prints i know
print(img1.size)
print(img1.mode)
print(img1.format)
print(img1)
# Out:
# (275, 183)
# RGB
# JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1D70956AAE0>

# %%
imgs = get_image_list(mydir)

# %%
new_size = (275, 183)
for img in imgs:
    img = img.resize(new_size)
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img1 = load_image(img1_path)

# %%
thumbnail_size = (100,100)
img1.thumbnail(thumbnail_size)
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x67>

# %%
new_image1 = mydir + '/newimg1.png'
img1.save(new_image1)

# %%
img1.close()
