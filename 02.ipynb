# %%
from PIL import Image
from imgtools import *

# %%
my_dir = 'C:/Users/user/Documents/Thị giác máy tính/image'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (275, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# (198, 200)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=198x200>
# (275, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# (183, 276)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x276>
